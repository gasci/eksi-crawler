# %% [markdown]
# [API Explanation](https://id.nlm.nih.gov/mesh/swagger/ui)

# %%
# importing the requests library
import requests
from pymongo import MongoClient
from collections import defaultdict
import time

# %%
mongo_cli_username = "healdash"
mongo_cli_password = input() # enter the password
# Out:
#  =Healdash34

# %%
client = MongoClient("mongodb+srv://{}:{}@cluster0.plop5.mongodb.net/myFirstDatabase?retryWrites=true&w=majority".format(mongo_cli_username, mongo_cli_password))
db = client['healdash']

# %%
# api-endpoint
URL = "https://id.nlm.nih.gov/mesh/sparql"

# %%
# input location
input_location = 'data/input/diseases-english.txt'

# %%
# keywords list
query_terms = []

with open(input_location) as my_file:
    for line in my_file:
        query_terms.append(line.replace("\n", ""))

# %%
query_terms[:2]
# Out:
# ['cleft lip', 'cleft palate']

# %%
class Mesh:
    def __init__(self):
        self.query_term = ""
        self.query = ""
        self.keyword_dict = defaultdict(list)
        self.keywords_to_update = []
        
    def update_query(self, query_term):
        self.query_term = query_term
        self.query = """
            PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
            PREFIX owl: <http://www.w3.org/2002/07/owl#>
            PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
            PREFIX mesh: <http://id.nlm.nih.gov/mesh/>

            SELECT ?d ?dName ?c ?cName ?t ?v
            WHERE { 
              # ?d a meshv:Descriptor .
              # ?d meshv:concept ?c .
              # ?d ?t ?c .
              # ?t rdfs:label ?v .
              # ?d rdfs:label ?dName .
              # ?c rdfs:label ?cName
              FILTER(REGEX(?dName,"%s",'i') || REGEX(?cName,"%s",'i')) 
            }
            """ % (query_term, query_term)
        
    def send_request(self, format="JSON", limit=1000, inference="true", offset=0):
        
        # defining a params dict for the parameters to be sent to the API
        PARAMS = {'query': self.query, 'format': format, 'limit': limit, 'offset': offset, 'inference': inference}
        
        # sending get request and saving the response as response object
        result = requests.get(url = URL, params = PARAMS)
                
        # extracting data in json format
        values_dict = result.json()['results']['bindings']
        
        temp_dict = defaultdict(list)
        existing_words = []
        temp_arr = []
        
        for sub in values_dict:
            temp_dict = defaultdict(list)
            temp_word = sub['cName']['value']
            
            if temp_word not in existing_words:
                temp_dict['resource'] = sub['c']['value']
                temp_dict['word'] = temp_word
                temp_dict['label'] = sub['dName']['value']
                temp_arr.append(temp_dict)
                existing_words.append(temp_word)
        
        self.keyword_dict[self.query_term] = temp_arr
        
    def get_keyword_synonyms(self, keywords: list) -> dict:
        
        for keyword in keywords:
            self.update_query(keyword)
            start_time = time.time()
            self.send_request()
            
            if len(self.keyword_dict[keyword]) != 0:
                # add data to mongodb
                print("{} - {:.0f} seconds".format(keyword, time.time() - start_time))
                db.mesh_synonyms.update_many({"keyword": keyword}, {"$set": {"synonyms": self.keyword_dict[keyword]}}, upsert=True)
            else:
                self.keywords_to_update.append(keyword)
                print("{} - No synonymns".format(keyword))
        
        return self.keyword_dict

# %%
mesh = Mesh()

# %%
keyword_dict = mesh.get_keyword_synonyms(ss)
print(keyword_dict)
# Out:
# reflux - 10 seconds
# defaultdict(<class 'list'>, {'cleft lip': [defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2018/M0004548', 'word': 'Cleft Lip', 'label': 'Cleft Lip'})], 'cleft palate': [defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2020/M0015763', 'word': 'Cleft Palate Prosthesis', 'label': 'Palatal Obturators'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2018/M0574709', 'word': 'Cleft Palate, Isolated', 'label': 'Cleft Palate'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2018/M0004549', 'word': 'Cleft Palate', 'label': 'Cleft Palate'})], 'behçet': [], 'herpes': [defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0027338', 'word': 'Alphaherpesvirinae', 'label': 'Alphaherpesvirinae'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0027344', 'word': 'Gammaherpesvirinae', 'label': 'Gammaherpesvirinae'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0334889', 'word': 'Meningoencephalitis, Herpes Simplex Virus', 'label': 'Encephalitis, Herpes Simplex'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0334886', 'word': 'Herpetic Acute Necrotizing Encephalitis', 'label': 'Encephalitis, Herpes Simplex'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0334876', 'word': 'Meningoencephalitis, Herpes Zoster', 'label': 'Encephalitis, Varicella Zoster'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0328381', 'word': 'Encephalitis, Herpes Simplex', 'label': 'Encephalitis, Herpes Simplex'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0376609', 'word': 'Herpesvirus 3, Gallid', 'label': 'Herpesvirus 3, Gallid'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0376870', 'word': 'Herpesvirus 4, Bovine', 'label': 'Herpesvirus 4, Bovine'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0376311', 'word': 'Herpesvirus 5, Bovine', 'label': 'Herpesvirus 5, Bovine'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0376738', 'word': 'Herpesvirus 1, Meleagrid', 'label': 'Herpesvirus 1, Meleagrid'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2015/M0027342', 'word': 'Herpesvirus 4, Equid', 'label': 'Herpesvirus 4, Equid'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2016/M0375851', 'word': 'Herpesvirus 16, Cercopithecine', 'label': 'Simplexvirus'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2016/M0027339', 'word': 'Herpesvirus 1, Saimiriine', 'label': 'Simplexvirus'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2016/M0357245', 'word': 'Herpes Simplex Virus Vaccines', 'label': 'Herpes Simplex Virus Vaccines'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2016/M0010284', 'word': 'Mouse Thymic Virus', 'label': 'Herpesviridae'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2016/M0010283', 'word': 'Thymic Group Viruses', 'label': 'Herpesviridae'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2016/M0010282', 'word': 'Herpesviridae', 'label': 'Herpesviridae'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2016/M0010287', 'word': 'Herpesvirus 1, Cercopithecine', 'label': 'Herpesvirus 1, Cercopithecine'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2016/M0002024', 'word': 'Herpesvirus 1, Gallid', 'label': 'Herpesvirus 1, Gallid'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2016/M0010286', 'word': 'Herpesvirus 2, Saimiriine', 'label': 'Herpesvirus 2, Saimiriine'}), defaultdict(<class 'list'>, {'resource': 'http://id.nlm.nih.gov/mesh/2016/M0022527', 'word': 'Herpesvirus 3, Human', 'label': 'Herpesvirus 3, Human'}), defaultdict(<class 'list'>, {'resourc ...
